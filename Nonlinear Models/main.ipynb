# %%
'-------------------------------- Load in regular libraries ------------------------------------'
import yaml
import time
import pandas as pd
import datetime as dt
import numpy as np
from IPython.display import clear_output
import matplotlib.pyplot as plt
from scipy.stats import norm
import arch

# %%
'-------------------------------- Load in custom libraries ------------------------------------'
from src.Machine_Learning import Principal_Component_Analysis

# %%
# Note: First create matrix A_full!

# Adjust data by subtracing column average:
A_PCA = PCA._data_adjustment(A_full)

# Singular Value Decomposition:
U, Sigma, V = PCA._singular_value_decomposition(A_PCA, mode = 'full', k = 10)

# Outlier Analysis -> Use matrix U!
rows_outliers = PCA._outlier_analysis(U, magnitude = 4)
